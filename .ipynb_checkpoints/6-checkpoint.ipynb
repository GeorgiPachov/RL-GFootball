# %% [markdown]
# ## Setup

# %%
! brew install git python3 cmake sdl2 sdl2_image sdl2_ttf sdl2_gfx boost boost-python3
! python3 -m pip install --upgrade pip setuptools psutil wheel

# %%
! pip install gfootball

# %%
! pip install setuptools==65.5.0
! git clone https://github.com/google-research/football.git
! cd football && pip install .

# %% [markdown]
# ### Test game play

# %%
! python -m gfootball.play_game --action_set=full
# Out:
# objc[81026]: Class SDLApplication is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368800) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x1321287e8). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDLAppDelegate is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368850) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128838). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDLTranslatorResponder is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x1063688c8) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x1321288b0). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDLMessageBoxPresenter is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x1063688f0) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x1321288d8). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDL_cocoametalview is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368940) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128928). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDLOpenGLContext is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368990) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128978). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDLWindow is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368b20) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x1321289c8). One of the two will be used. Which one is undefined.
# objc[81026]: Class Cocoa_WindowListener is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368b48) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x1321289f0). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDLView is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368bc0) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128a68). One of the two will be used. Which one is undefined.
# objc[81026]: Class METAL_RenderData is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368c38) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128ab8). One of the two will be used. Which one is undefined.
# objc[81026]: Class METAL_TextureData is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368c88) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128b08). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDL_RumbleMotor is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368cb0) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128b58). One of the two will be used. Which one is undefined.
# objc[81026]: Class SDL_RumbleContext is implemented in both /opt/homebrew/Cellar/sdl2/2.26.3/lib/libSDL2-2.0.0.dylib (0x106368d00) and /Users/georgipachov/opt/miniconda3/envs/rl/lib/python3.10/site-packages/pygame/.dylibs/libSDL2-2.0.0.dylib (0x132128ba8). One of the two will be used. Which one is undefined.
# pygame 2.2.0 (SDL 2.0.22, Python 3.10.6)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# UNSUPPORTED (log once): POSSIBLE ISSUE: unit 1 GLD_TEXTURE_INDEX_2D is unloadable and bound to sampler type (Float) - using zero texture because texture unloadable
# ^C
# W0307 11:21:45.448897 4385031552 play_game.py:65] Game stopped, writing dump...
# I0307 11:21:45.453339 4385031552 observation_processor.py:361] Dump written to /var/folders/4x/vb5tl80s45v2f_k7_zb004bc0000gn/T/dumps/shutdown_20230307-112145449051.dump
# I0307 11:21:45.572648 4385031552 observation_processor.py:361] Dump written to /var/folders/4x/vb5tl80s45v2f_k7_zb004bc0000gn/T/dumps/episode_done_20230307-112130066776.dump

# %% [markdown]
# ### Learning environment

# %%
import torch
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.distributions import Categorical
import gym
import numpy as np
import matplotlib.pyplot as plt
import os
from collections import namedtuple
import gfootball
import gfootball.env as football_env
from gfootball.env.wrappers import Simple115StateWrapper
import collections

SavedAction = namedtuple('SavedAction', ['log_prob', 'value'])
        
def obs_transform(obs):
    return Simple115StateWrapper.convert_observation(obs, True)


def create_env(render=False, 
               env_name='academy_empty_goal', 
               wrapper_init=None,
               record=True,
               **params):
    if env_name == 'cart_pole':
        env = gym.make('CartPole-v0')
    else:
        env_names = ['1_vs_1_easy', '5_vs_5', 'academy_run_to_score', 'academy_empty_goal_close', 'academy_empty_goal']
        os.environ['MESA_GL_VERSION_OVERRIDE'] = '3.3'
        env = football_env.create_environment(env_name=env_name, 
                                              stacked=False, 
                                              representation='raw',
                                              rewards='scoring,checkpoints',
                                              logdir='replays', 
                                              write_goal_dumps=record, 
                                              write_full_episode_dumps=record, 
                                              write_video=record,
                                              render=render)
        if wrapper_init is not None:
            return wrapper_init.__call__(env)
        else:
            return env


class Policy(nn.Module):
    """
    implements both actor and critic in one model
    """
    def __init__(self):
        super(Policy, self).__init__()
        self.affine1 = nn.Linear(115, 128)

        # actor's layer
        self.action_head = nn.Linear(128, 19)

        # critic's layer
        self.value_head = nn.Linear(128, 1)

        # action & reward buffer
        self.saved_actions = []
        self.rewards = []

    def forward(self, x):
        """
        forward of both actor and critic
        """
        x = F.relu(self.affine1(x))

        # actor: choses action to take from state s_t 
        # by returning probability of each action
        action_prob = F.softmax(self.action_head(x), dim=-1)

        # critic: evaluates being in the state s_t
        state_values = self.value_head(x)

        # return values for both actor and critic as a tuple of 2 values:
        # 1. a list with the probability of each action over the action space
        # 2. the value from state s_t 
        return action_prob, state_values


def select_action(model, state, in_training):
    state = torch.from_numpy(state).float()
    probs, state_value = model(state)

    # create a categorical distribution over the list of probabilities of actions
    m = Categorical(probs)

    # and sample an action using the distribution
    action = m.sample()

    return action.item(), SavedAction(m.log_prob(action), state_value)


def replay_episode_and_update(saved_actions, rewards, optimizer, gamma, finish=False, eps=1e-8):
    """
    Training code. Calculates actor and critic loss and performs backprop.
    """

    # reset gradients
    optimizer.zero_grad()

    R = 0
    policy_losses = [] # list to save actor (policy) loss
    value_losses = [] # list to save critic (value) loss
    returns = [] # list to save the true values
    # calculate the true value using rewards returned from the environment
    for r in rewards[::-1]:
        # calculate the discounted value
        R = r + gamma * R
        returns.insert(0, R)

    returns = torch.tensor(returns)
    returns = (returns - returns.mean()) / (returns.std() + eps)

    for (log_prob, value), R in zip(saved_actions, returns):
        advantage = R - value.item()

        # calculate actor (policy) loss 
        policy_losses.append(-log_prob * advantage)

        # calculate critic (value) loss using L1 smooth loss
        value_losses.append(F.smooth_l1_loss(value, torch.tensor([R])))


    # sum up all the values of policy_losses and value_losses
    loss = torch.stack(policy_losses).sum() + torch.stack(value_losses).sum()

    # perform backprop
    loss.backward(retain_graph=finish)

    # Update weights
    optimizer.step()
            
    return torch.stack(policy_losses).sum().detach().numpy(),torch.stack(value_losses).sum().detach().numpy()


class DistanceFromOpponentGoalReward(gym.Wrapper):
        def __init__(self, env):
            super().__init__(env)
            self._env = env
        
        def step(self, action):
            obs, reward, done, info = self._env.step(action)
            reward = 0
            
            obs = obs[0]

            bx, by, bz = obs['ball']
            ogx, ogy = -1, 0
            
            dist_from_opponent_goal = (np.sqrt((bx-ogx)**2 + (by-ogy)**2))
            reward -= dist_from_opponent_goal
            
            return obs, reward, done, info
        

class DistanceFromOpponentGoalRewardFixed(gym.Wrapper):
    def __init__(self, env):
        super().__init__(env)
        self._env = env
        self._last_ball_pos = [0, 0, 0]

    def step(self, action):
        obs, reward, done, info = self._env.step(action)
        reward = 0

        obs = obs[0]
        goals_left_team = obs['score'][0]
        if goals_left_team > 0:
            print('Goal discovered!')
            # reward += goals_left_team * 100_000
#         lost_ball = obs['ball_owned_team'] != -1
#         if lost_ball:
#             reward -=1

        bx, by, bz = obs['ball']
        ogx, ogy = 1+0.05, 0
        
        # Positive reward for distance from opponent players
        for i in range(len(obs['right_team'])):
            if obs['right_team_roles'][i] != 0: # 0 = goalkeeper:
                px, py = obs['right_team'][i]
                dist_from_ball = np.sqrt((bx-px)**2 + (by-py)**2)
                reward +=dist_from_ball
                
            # Force the team to avoid the ball going close to the goalkeeper
            elif obs['right_team_roles'][i] == 0: # 0 = goalkeeper:
                px, py = obs['right_team'][i]
                dist_from_ball = np.sqrt((bx-px)**2 + (by-py)**2)
                reward +=dist_from_ball*0.5

        # Negative reward for distance from opposition goal
        dist_from_opponent_goal = (np.sqrt((bx-ogx)**2 + (by-ogy)**2))
        reward -= dist_from_opponent_goal

        # Negative time penalty
        # reward -= 0.1
        
        # Positive ball velocity reward
        # Calculate ball velocity
        # velocity = np.sqrt(np.sum((obs['ball'] - self._last_ball_pos)**2))
        # reward += velocity

        self._last_ball_pos=obs['ball']
            
        return obs, reward, done, info
    
def run_agent(exp_name='exp1',
              model=None,
              train=True,
              replay_memory_goals=True,
              replay_memory_times=1,
              replay_memory_learning_rate=1e-2,
              render=False,
              record=False, 
              num_episodes=2000,
              num_steps=500,
              task='academy_empty_goal_close',
              wrapper_init=DistanceFromOpponentGoalReward,
              policy_fn=Policy,
              solved_threshold=-25,
              log_every=50,
              learning_rate=1e-2,
              gamma=0.99,
              last_n=5,
              seed=0,
              checkpoint=True,
              checkpoint_dir='checkpoints'
             ):
    # set seed first
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    
    if not train:
        model.eval()
                
    if not os.path.exists(checkpoint_dir):
        os.mkdir(checkpoint_dir)
    
    try: 
        max_reward = -1_000_000
        running_reward = 0
        policy_losses = []
        critic_losses = []
        episodes_rewards = []
        env = create_env(render=render, 
                         env_name=task,
                         record=record,
                         wrapper_init=wrapper_init)
        if model is None:
            model = policy_fn()
            
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        # eps = np.finfo(np.float32).eps.item()
        eps = 1e-8
        
        saved_episodes = []
        for i_episode in range(num_episodes):
            # reset environment and episode reward
            episode_actions = []
            episode_states = []
            episode_rewards = []

            discard_episode = True
            
            # reset state
            state = env.reset()
            state = obs_transform(state)

            # play the episode
            for t in range(1, num_steps):
                # select action from policy
                action, savedAction = select_action(model, state, train)
                episode_actions.append(savedAction)

                # take the action
                state, reward, done, _ = env.step(action)
                
                if state['score'][0] > 0:
                    discard_episode = False
                
                state = obs_transform([state])
                episode_states.append(state)
                
                episode_rewards.append(reward)
                if done:
                    break

                    
            # log results
            ep_reward= np.sum(episode_rewards)
            episodes_rewards.append(ep_reward)
            
            # save episode if needed
            if not discard_episode:
                saved_episodes.append([episode_states, episode_actions, episode_rewards]) 
            
            # update cumulative reward
            running_reward = np.mean(episodes_rewards[-last_n:])
            
            if i_episode % log_every == 0:
                print(f'Episode: {i_episode}\tLast reward: {ep_reward:.2f} \t Last {last_n} episodes average reward: {running_reward}')

            if train:
                # save checkpoint
                if checkpoint:
                    if running_reward > max_reward:
                        torch.save(model, f'{checkpoint_dir}/{running_reward}_{task}_{exp_name}_checkpoint_{i_episode}.h5')
                        max_reward = running_reward

                if i_episode > last_n and running_reward > solved_threshold:
                    torch.save(model, f'{task}_{exp_name}.h5')
                    print('Solved!')
                    return model, episodes_rewards
                
                else:
                    # perform backprop
                    policy_loss, critic_loss = replay_episode_and_update(episode_actions, episode_rewards, optimizer, gamma, finish=True)
                    policy_losses.append(policy_loss)
                    critic_losses.append(critic_loss)
        
        
        if train and replay_memory_goals:
            # Replay best episodes once
            print(f'Replaying {replay_memory_times} times best {len(saved_episodes)} episodes with lr={replay_memory_learning_rate}...')
            
            optimizer = optim.Adam(model.parameters(), lr=replay_memory_learning_rate)
            for _ in range(replay_memory_times):
                for (states, actions, rewards) in saved_episodes:
                    env.reset()
                    episode_actions = []
                    episode_rewards = []
                    # play the episode
                    for t in range(1, num_steps):
                        state = states[t-1]
                        reward = rewards[t-1]

                        # select action from policy
                        action, savedAction = select_action(model, state, train)
                        episode_actions.append(savedAction)

                        # take the action
                        _, reward, done, __ = env.step(action)

                        episode_rewards.append(reward)
                        if done or t == len(states)-1:
                            break


                    # log results
                    ep_reward= np.sum(episode_rewards)
                    episodes_rewards.append(ep_reward)

                    # update cumulative reward
                    running_reward = np.mean(episodes_rewards[-last_n:])

                    if i_episode % log_every == 0:
                        print(f'Episode: {i_episode}\tLast reward: {ep_reward:.2f} \t Last {last_n} episodes average reward: {running_reward}')

                    # perform backprop
                    policy_loss, critic_loss = replay_episode_and_update(episode_actions, episode_rewards, optimizer, gamma, finish=True)
                    policy_losses.append(policy_loss)
                    critic_losses.append(critic_loss)
                    
        policy_losses = [p.reshape(-1)[0] for p in policy_losses]
        critic_losses = [p.reshape(-1)[0] for p in critic_losses]
        return model, episodes_rewards, policy_losses, critic_losses
    finally: 
        env.close()
        
def load_best_agent(checkpoints_dir='checkpoints'):
    # Load best agent
    checkpoints = os.listdir(checkpoints_dir)
    all_checkpoints = {int(x[:x.index('.')]):x for x in checkpoints}
    max_reward = max(all_checkpoints.keys())
    best = all_checkpoints[max_reward]
    print('Loading checkpoint: ', best)
    model_loaded = torch.load(os.path.join(checkpoints_dir, best))
    return model_loaded

def load_agent(name, checkpoints_dir='checkpoints'):
    # Load manually
    print('Loading checkpoint: ', name)
    model_loaded = torch.load(os.path.join(checkpoints_dir, name))
    return model_loaded

# %% [markdown]
# ### Learning objective: 3 vs 1

# %%
# Without replay memory
last_n=10
model, episode_rewards, policy_losses, critic_losses = run_agent(train=True,
                                   replay_memory_goals=False,
                                   render=False,
                                   record=False,
                                   log_every=50,
                                   num_steps=250,
                                   num_episodes=1000,
                                   seed=42,
                                   last_n=last_n,
                                   solved_threshold=20_000, 
                                   task='academy_run_pass_and_shoot_with_keeper', 
                                   learning_rate=1e-2,
                                   wrapper_init=DistanceFromOpponentGoalRewardFixed)

pd.Series(episode_rewards).rolling(last_n).mean().plot(xlabel='Еpisode', ylabel='Reward', title=f'Average reward for {last_n} episodes')
plt.show()
pd.Series(policy_losses).plot(title='Policy loss')
plt.show()
pd.Series(critic_losses).plot(title='Critic loss')
plt.show()
# Out:
# Episode: 0	Last reward: -5.31 	 Last 10 episodes average reward: -5.308816045787216
# /var/folders/4x/vb5tl80s45v2f_k7_zb004bc0000gn/T/ipykernel_30595/3757458203.py:126: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_losses.append(F.smooth_l1_loss(value, torch.tensor([R])))
# Episode: 50	Last reward: 1.27 	 Last 10 episodes average reward: 1.3347302047964618
# Episode: 100	Last reward: 1.55 	 Last 10 episodes average reward: 1.4178933955449675
# Episode: 150	Last reward: 1.29 	 Last 10 episodes average reward: 1.3756887075227933
# Episode: 200	Last reward: 1.37 	 Last 10 episodes average reward: 1.429092735187035
# Episode: 250	Last reward: 1.25 	 Last 10 episodes average reward: 1.4024723024845176
# Episode: 300	Last reward: 1.36 	 Last 10 episodes average reward: 1.3356888185238427
# Episode: 350	Last reward: 0.69 	 Last 10 episodes average reward: -1.3030727804668996
# Episode: 400	Last reward: 1.32 	 Last 10 episodes average reward: 1.4390135485223927
# Episode: 450	Last reward: 1.44 	 Last 10 episodes average reward: 0.11149294262547613
# Episode: 500	Last reward: 1.56 	 Last 10 episodes average reward: 1.3409170684607836
# Episode: 550	Last reward: 1.31 	 Last 10 episodes average reward: 1.4076598438178862
# Episode: 600	Last reward: 1.52 	 Last 10 episodes average reward: 1.4579529960066477
# Episode: 650	Last reward: 1.53 	 Last 10 episodes average reward: 1.4185814172875628
# Episode: 700	Last reward: 1.26 	 Last 10 episodes average reward: 1.4376520333782206
# Episode: 750	Last reward: 1.47 	 Last 10 episodes average reward: 1.4051246492176115
# Episode: 800	Last reward: 1.41 	 Last 10 episodes average reward: 1.380238874133853
# Episode: 850	Last reward: 1.39 	 Last 10 episodes average reward: 1.4545241847322399
# Episode: 900	Last reward: 1.54 	 Last 10 episodes average reward: 1.4513049278888954
# Episode: 950	Last reward: -22.42 	 Last 10 episodes average reward: -7.662046249020958

# %%
policy, er, _, __ = run_agent(model=model, 
          train=False, 
          render=True, 
          record=True,
          seed=0, 
          num_episodes=1,
          num_steps=250,
          task='academy_run_pass_and_shoot_with_keeper', 
          wrapper_init=DistanceFromOpponentGoalRewardFixed)

episodes_with_goals = len([e for e in er if e > 0])
print(f'Episodes with goals: {episodes_with_goals} from total {len(er)}')
# Out:
# UNSUPPORTED (log once): POSSIBLE ISSUE: unit 1 GLD_TEXTURE_INDEX_2D is unloadable and bound to sampler type (Float) - using zero texture because texture unloadable
# Episode: 0	Last reward: -72.22 	 Last 5 episodes average reward: -72.21655030264752
# Episodes with goals: 0 from total 1

# %%
policy, er, _, __ = run_agent(model=model, 
          train=False, 
          render=True, 
          record=True,
          seed=0, 
          num_episodes=106,
          num_steps=50,
          task='academy_3_vs_1_with_keeper', 
          wrapper_init=DistanceFromOpponentGoalRewardFixed)

episodes_with_goals = len([e for e in er if e > 0])
print(f'Episodes with goals: {episodes_with_goals} from total {len(er)}')
# Out:
# Episode: 0	Last reward: -7.59 	 Last 5 episodes average reward: -7.593694956913388
# Episode: 50	Last reward: -1.01 	 Last 5 episodes average reward: -0.8807467722748916
# Goal discovered!
# Goal discovered!
# Episode: 100	Last reward: -1.03 	 Last 5 episodes average reward: -2.307179947206086
# Episodes with goals: 15 from total 106

# %%
# Save 6% goal rate
torch.save(model, '6_%_goal_rate_3_vs_1.h5')

# %%
21

# %%
# With replay memory
last_n=10
model, episode_rewards, policy_losses, critic_losses = run_agent(train=True,
                                   replay_memory_goals=True,
                                   replay_memory_times=100,
                                   replay_memory_learning_rate=5e-2,
                                   render=False,
                                   record=False,
                                   log_every=100,
                                   num_steps=50,
                                   num_episodes=10_000,
                                   seed=42,
                                   last_n=last_n,
                                   solved_threshold=20_000, 
                                   task='academy_3_vs_1_with_keeper', 
                                   learning_rate=5e-2,
                                   wrapper_init=DistanceFromOpponentGoalRewardFixed)
pd.Series(episode_rewards).rolling(last_n).mean().plot(xlabel='Еpisode', ylabel='Reward', title=f'Average reward for {last_n} episodes')
plt.show()
pd.Series(policy_losses).plot(title='Policy loss')
plt.show()
pd.Series(critic_losses).plot(title='Critic loss')
plt.show()


policy, er, _, __ = run_agent(model=model, 
          train=False, 
          render=False, 
          record=False,
          seed=42, 
          num_episodes=100,
          num_steps=50,
          task='academy_3_vs_1_with_keeper', 
          wrapper_init=DistanceFromOpponentGoalRewardFixed)

episodes_with_goals = len([e for e in er if e > 0])
print(f'Episodes with goals: {episodes_with_goals} from total {len(er)}')
# Out:
# Episode: 0	Last reward: -0.67 	 Last 10 episodes average reward: -0.6658576409352165
# /var/folders/4x/vb5tl80s45v2f_k7_zb004bc0000gn/T/ipykernel_93446/3812083269.py:126: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   value_losses.append(F.smooth_l1_loss(value, torch.tensor([R])))
# Episode: 100	Last reward: 1.02 	 Last 10 episodes average reward: -1.3308403465849203
# Goal discovered!
# Goal discovered!
# Episode: 200	Last reward: -1.04 	 Last 10 episodes average reward: -1.2599184655498357
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 300	Last reward: -2.31 	 Last 10 episodes average reward: 0.41856601235736546
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 400	Last reward: 0.82 	 Last 10 episodes average reward: 0.1377020793550626
# Episode: 500	Last reward: 3.60 	 Last 10 episodes average reward: 1.038842656304231
# Goal discovered!
# Goal discovered!
# Episode: 600	Last reward: -0.02 	 Last 10 episodes average reward: -0.6389582454688588
# Goal discovered!
# Episode: 700	Last reward: 0.09 	 Last 10 episodes average reward: 0.12452028588912052
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 800	Last reward: 0.04 	 Last 10 episodes average reward: 0.42610208602212474
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 900	Last reward: 0.09 	 Last 10 episodes average reward: 0.18560751344511878
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 1000	Last reward: 0.71 	 Last 10 episodes average reward: 0.6309048102081531
# Goal discovered!
# Episode: 1100	Last reward: 0.95 	 Last 10 episodes average reward: 0.5073078223632737
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 1200	Last reward: -0.03 	 Last 10 episodes average reward: 0.26595577219406935
# Goal discovered!
# Goal discovered!
# Episode: 1300	Last reward: 1.64 	 Last 10 episodes average reward: 0.9394244520346848
# Goal discovered!
# Goal discovered!
# Episode: 1400	Last reward: 0.07 	 Last 10 episodes average reward: 0.2704517544270596
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 1500	Last reward: 1.69 	 Last 10 episodes average reward: 1.0972481246582118
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 1600	Last reward: 0.85 	 Last 10 episodes average reward: -0.5524523389774322
# Goal discovered!
# Episode: 1700	Last reward: -0.00 	 Last 10 episodes average reward: 0.10205611829768794
# Goal discovered!
# Episode: 1800	Last reward: 2.15 	 Last 10 episodes average reward: 0.7833825956539286
# Goal discovered!
# Goal discovered!
# Episode: 1900	Last reward: 0.82 	 Last 10 episodes average reward: 0.6786241784688396
# Goal discovered!
# Goal discovered!
# Episode: 2000	Last reward: 2.15 	 Last 10 episodes average reward: 0.1197416553029621
# Goal discovered!
# Episode: 2100	Last reward: 0.93 	 Last 10 episodes average reward: 0.8898895665549302
# Goal discovered!
# Goal discovered!
# Episode: 2200	Last reward: 1.69 	 Last 10 episodes average reward: 0.6976684413613465
# Goal discovered!
# Episode: 2300	Last reward: 0.12 	 Last 10 episodes average reward: 0.19432796652373235
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 2400	Last reward: 0.10 	 Last 10 episodes average reward: 0.661927530658266
# Episode: 2500	Last reward: 1.24 	 Last 10 episodes average reward: 0.6684534988552108
# Goal discovered!
# Goal discovered!
# Episode: 2600	Last reward: 0.32 	 Last 10 episodes average reward: 0.2891502852168397
# Goal discovered!
# Episode: 2700	Last reward: -0.08 	 Last 10 episodes average reward: 0.39393640440871036
# Goal discovered!
# Goal discovered!
# Episode: 2800	Last reward: -0.75 	 Last 10 episodes average reward: 0.15020212942919248
# Goal discovered!
# Episode: 2900	Last reward: 1.84 	 Last 10 episodes average reward: 0.9891766144459675
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 3000	Last reward: 0.04 	 Last 10 episodes average reward: 0.5028430395659379
# Goal discovered!
# Goal discovered!
# Episode: 3100	Last reward: 0.03 	 Last 10 episodes average reward: 0.8627047705854707
# Goal discovered!
# Goal discovered!
# Episode: 3200	Last reward: 0.98 	 Last 10 episodes average reward: -0.11000901042394898
# Goal discovered!
# Episode: 3300	Last reward: 0.70 	 Last 10 episodes average reward: 0.5910448578076104
# Goal discovered!
# Goal discovered!
# Episode: 3400	Last reward: -0.55 	 Last 10 episodes average reward: 0.9280841707528348
# Goal discovered!
# Episode: 3500	Last reward: 0.61 	 Last 10 episodes average reward: 0.6650563203053059
# Goal discovered!
# Episode: 3600	Last reward: 0.05 	 Last 10 episodes average reward: 0.60987712361734
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 3700	Last reward: 0.08 	 Last 10 episodes average reward: 0.5929058132330656
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 3800	Last reward: 0.32 	 Last 10 episodes average reward: 0.3872875290828402
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 3900	Last reward: 1.01 	 Last 10 episodes average reward: 0.5155532457530574
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 4000	Last reward: 0.83 	 Last 10 episodes average reward: 0.933270548786209
# Goal discovered!
# Goal discovered!
# Episode: 4100	Last reward: 0.40 	 Last 10 episodes average reward: 0.39931084300792896
# Goal discovered!
# Episode: 4200	Last reward: -1.83 	 Last 10 episodes average reward: -0.02737968873671919
# Goal discovered!
# Episode: 4300	Last reward: 0.69 	 Last 10 episodes average reward: 0.36155897635828677
# Goal discovered!
# Episode: 4400	Last reward: 0.10 	 Last 10 episodes average reward: 1.0103709792366866
# Goal discovered!
# Episode: 4500	Last reward: 0.56 	 Last 10 episodes average reward: -0.32679115784659307
# Goal discovered!
# Goal discovered!
# Episode: 4600	Last reward: -0.21 	 Last 10 episodes average reward: 0.3007182344253424
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 4700	Last reward: 0.03 	 Last 10 episodes average reward: 0.06604821791506191
# Goal discovered!
# Episode: 4800	Last reward: 1.67 	 Last 10 episodes average reward: 0.4709738333796496
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 4900	Last reward: 0.79 	 Last 10 episodes average reward: 1.126911428551907
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 5000	Last reward: 2.12 	 Last 10 episodes average reward: 0.6900246563909856
# Episode: 5100	Last reward: 1.74 	 Last 10 episodes average reward: 1.0105694010446113
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 5200	Last reward: -0.03 	 Last 10 episodes average reward: 0.5615768382901958
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 5300	Last reward: 2.12 	 Last 10 episodes average reward: 0.9258474450808218
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 5400	Last reward: 0.63 	 Last 10 episodes average reward: 0.8064153563709475
# Goal discovered!
# Goal discovered!
# Episode: 5500	Last reward: -0.32 	 Last 10 episodes average reward: -0.27853663826495967
# Episode: 5600	Last reward: 1.08 	 Last 10 episodes average reward: 0.7334636892826669
# Goal discovered!
# Goal discovered!
# Episode: 5700	Last reward: -0.68 	 Last 10 episodes average reward: 0.5829996430330191
# Episode: 5800	Last reward: 0.25 	 Last 10 episodes average reward: 0.7255494303522241
# Goal discovered!
# Episode: 5900	Last reward: 0.40 	 Last 10 episodes average reward: 0.1372571725705986
# Goal discovered!
# Goal discovered!
# Episode: 6000	Last reward: 1.97 	 Last 10 episodes average reward: 0.4619810743029159
# Episode: 6100	Last reward: -0.16 	 Last 10 episodes average reward: 0.6069513778460228
# Goal discovered!
# Goal discovered!
# Episode: 6200	Last reward: -0.04 	 Last 10 episodes average reward: 0.7932759240429665
# Goal discovered!
# Episode: 6300	Last reward: 0.03 	 Last 10 episodes average reward: 0.4416993152425988
# Episode: 6400	Last reward: 1.63 	 Last 10 episodes average reward: 0.4558294672504748
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 6500	Last reward: 1.77 	 Last 10 episodes average reward: 0.9121927575430508
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 6600	Last reward: 0.06 	 Last 10 episodes average reward: -0.7025766053087844
# Goal discovered!
# Goal discovered!
# Episode: 6700	Last reward: 3.14 	 Last 10 episodes average reward: 0.845563660951196
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 6800	Last reward: 0.04 	 Last 10 episodes average reward: 0.4269144398150452
# Goal discovered!
# Episode: 6900	Last reward: -0.14 	 Last 10 episodes average reward: 0.41252155867859297
# Goal discovered!
# Episode: 7000	Last reward: -0.12 	 Last 10 episodes average reward: 0.10451008389697058
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 7100	Last reward: 1.11 	 Last 10 episodes average reward: 0.5255160408671907
# Goal discovered!
# Goal discovered!
# Episode: 7200	Last reward: 1.87 	 Last 10 episodes average reward: 1.0644788366797768
# Goal discovered!
# Episode: 7300	Last reward: 0.92 	 Last 10 episodes average reward: 0.4577127111434011
# Goal discovered!
# Episode: 7400	Last reward: -0.01 	 Last 10 episodes average reward: 0.5162445585084618
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 7500	Last reward: -0.61 	 Last 10 episodes average reward: 0.14580907794148337
# Goal discovered!
# Goal discovered!
# Episode: 7600	Last reward: 1.46 	 Last 10 episodes average reward: 0.45974755046723736
# Episode: 7700	Last reward: 0.10 	 Last 10 episodes average reward: 1.0824669344415678
# Episode: 7800	Last reward: 1.72 	 Last 10 episodes average reward: 1.0482593247370717
# Goal discovered!
# Goal discovered!
# Episode: 7900	Last reward: 2.09 	 Last 10 episodes average reward: -0.0993051159389005
# Episode: 8000	Last reward: 0.14 	 Last 10 episodes average reward: 0.8194270903741392
# Goal discovered!
# Episode: 8100	Last reward: 0.11 	 Last 10 episodes average reward: 1.135454974066014
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 8200	Last reward: 2.12 	 Last 10 episodes average reward: 1.2797471976521035
# Goal discovered!
# Goal discovered!
# Episode: 8300	Last reward: 1.31 	 Last 10 episodes average reward: 0.9028531786377707
# Episode: 8400	Last reward: 1.09 	 Last 10 episodes average reward: 0.639782657344662
# Goal discovered!
# Episode: 8500	Last reward: 2.00 	 Last 10 episodes average reward: 1.0161434782819927
# Episode: 8600	Last reward: 0.84 	 Last 10 episodes average reward: 1.1758194403417348
# Episode: 8700	Last reward: -0.01 	 Last 10 episodes average reward: 0.2098988586833075
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 8800	Last reward: -0.09 	 Last 10 episodes average reward: 0.30973181774886605
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 8900	Last reward: 1.65 	 Last 10 episodes average reward: 1.5001904100167562
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 9000	Last reward: 1.73 	 Last 10 episodes average reward: 0.7235878980726691
# Goal discovered!
# Episode: 9100	Last reward: 1.01 	 Last 10 episodes average reward: 0.69247612809213
# Goal discovered!
# Episode: 9200	Last reward: 0.22 	 Last 10 episodes average reward: 0.5044360609031882
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 9300	Last reward: 0.18 	 Last 10 episodes average reward: 0.5472612914218857
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 9400	Last reward: 1.18 	 Last 10 episodes average reward: 0.7362523841748454
# Goal discovered!
# Goal discovered!
# Episode: 9500	Last reward: 0.26 	 Last 10 episodes average reward: 0.924323031363026
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 9600	Last reward: 1.97 	 Last 10 episodes average reward: -0.1524102466075597
# Goal discovered!
# Goal discovered!
# Episode: 9700	Last reward: 1.19 	 Last 10 episodes average reward: 0.8537332273535825
# Goal discovered!
# Goal discovered!
# Episode: 9800	Last reward: 2.27 	 Last 10 episodes average reward: 0.7808081788405847
# Episode: 9900	Last reward: 1.57 	 Last 10 episodes average reward: 1.112626234705491
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Replaying 100 times best 214 episodes with lr=0.05...
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episode: 0	Last reward: 0.15 	 Last 5 episodes average reward: 0.14875276259224485
# Episode: 50	Last reward: 0.02 	 Last 5 episodes average reward: 0.18067725108682448
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Goal discovered!
# Episodes with goals: 62 from total 100

# %%
policy, er, _, _ = run_agent(model=model, 
          train=False, 
          render=True, 
          record=True,
          seed=42, 
          num_episodes=500,
          num_steps=50,
          task='academy_3_vs_1_with_keeper', 
          wrapper_init=DistanceFromOpponentGoalRewardFixed)

episodes_with_goals = len([e for e in er if e > 0])
print(f'Episodes with goals: {episodes_with_goals} from total {len(er)}')
# Out:
# Episode: 0	Last reward: 0.82 	 Last 5 episodes average reward: 0.8151792591628941
